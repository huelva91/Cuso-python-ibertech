# %% [markdown]
# ### Ejercicio 7. Composicion. Supermercado

# %% [markdown]
# -Television
# +id
# +marca
# +pulgadas
# +precio
#
# -Ordenador
# +id
# +marca
# +capacidad_disco_duro
# +ram
# +precio
#
# -Monitor
# +id
# +marca
# +pulgadas
# +precio
#
# -Cliente
# +nombre
# +tipo (VIP o no)
# +carrito_compra: listado[productos]
# +pagar()
#
# -Cajera
# +numero_empleado
# +nombre
# +atender_cliente()
#
# -Tienda
# 3 clientes
# 2 cajeras
#
# Cada cliente va llenar la cesta con uno o varios productos
#
# cajeras van a ir atendiendo a los clientes
#
#
# Si cliente es VIP, 15% en la compra

# %%
class Television:
    def __init__(self, id, marca, pulgadas, precio):
        self.id = id
        self.marca = marca
        self.pulgadas = pulgadas
        self.precio = precio


class Ordenador:
    def __init__(self, id, marca, capacidad_disco_duro, ram, precio):
        self.id = id
        self.marca = marca
        self.capacidad_disco_duro = capacidad_disco_duro
        self.ram = ram
        self.precio = precio


class Monitor:
    def __init__(self, id, marca, pulgadas, precio):
        self.id = id
        self.marca = marca
        self.pulgadas = pulgadas
        self.precio = precio


class Cliente:
    def __init__(self, nombre, tipo, carrito_compra=[]):
        self.nombre = nombre
        self.tipo = tipo
        self.carrito_compra = carrito_compra

    def pagar(self):
        pass


class Cajera:
    def __init__(self, numero_empleado, nombre):
        self.numero_empleado = numero_empleado
        self.nombre = nombre

    def atender_cliente(self):
        pass

class Tienda:
    def __init__(self):
        pass


television1 = Television("1T", "LG", 55, 1000)
ordenador1 = Ordenador("1o", "HP", 1000, 8, 850)
monitor1 = Monitor("1M", "Samsung", 32, 400)

cliente1 = Cliente("Ana", True )
cliente2 = Cliente("Paco", False )
cliente3 = Cliente("Lucia", True )

carrito_compra = [television1, ordenador1, monitor1]

cliente1.carrito_compra = carrito_compra
cliente2.carrito_compra = carrito_compra
cliente3.carrito_compra = carrito_compra

cajera1 = Cajera(1, "Maria")
cajera2 = Cajera(2, "Sergio")


lista_clientes = [cliente1, cliente2, cliente3]
